# %%
import json
from bs4 import *

from bs4 import BeautifulSoup, Tag
import json

def tag_to_dict(tag):
    """Convert a BeautifulSoup Tag to a dictionary."""
    if not isinstance(tag, Tag):
        return str(tag)
    
    return {
        'name': tag.name,
        'attrs': dict(tag.attrs),
        'contents': [tag_to_dict(child) for child in tag.contents]
    }

def dict_to_tag(d):
    """Convert a dictionary back to a BeautifulSoup Tag."""
    if not isinstance(d, dict):
        return d
    
    # Create a new Tag
    soup = BeautifulSoup("", 'html.parser')
    tag = soup.new_tag(d['name'])
    
    # Add attributes
    for key, value in d['attrs'].items():
        tag[key] = value
    
    # Add contents
    for content in d['contents']:
        if isinstance(content, dict):
            tag.append(dict_to_tag(content))
        else:
            tag.append(content)
    
    return tag

def load_chapters_from_json(filename):
    """Load chapters from JSON file and convert back to Tags."""
    with open(filename, 'r', encoding='utf-8') as fp:
        loaded_dict = json.load(fp)
    
    restored_dict = {}
    for title, content in loaded_dict.items():
        restored_dict[title] = [
            (type_info, dict_to_tag(tag_dict) if isinstance(tag_dict, dict) else tag_dict)
            for type_info, tag_dict in content
        ]
    
    return restored_dict

    
restored_book = load_chapters_from_json('Leadership_Kissinger.json')

# %%
for k in restored_book.keys():
    for i, entry in enumerate(restored_book[k]):
        restored_book[k][i] = (entry[0], entry[1].get_text())

# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4")
total = []

for k in restored_book.keys():
    total_paragraph = []
    print(f"{k} -> ")
    group = 1

    previous_title = None
    for i, entry in enumerate(restored_book[k]):
        if entry[0] == 'title':
            if total:
                print(f"Section {group} {previous_title}: {int(sum(total))} tokens for {len(total)} paragraphs")
                total = []
                group += 1
                previous_title = entry[1]
            else:
                previous_title = entry[1]
        
        if entry[0] == 'paragraph':
            cnt = len(encoding.encode(entry[1]))
            total.append(cnt)
            restored_book[k][i] = (entry[0], entry[1], cnt)
            
    print(f"Section {group}: {int(sum(total))} tokens for {len(total)} paragraphs")
    print("---------------------------------------------")
    print()
# Out:
# Introduction ->
# Section 1 The Axes of Leadership: 579 tokens for 5 paragraphs
# Section 2 The Nature of Leadership Decisions: 1669 tokens for 10 paragraphs
# Section 3 Six Leaders in Their Context: 2301 tokens for 21 paragraphs
# Section 4 Epitomes of Leadership: The Statesman and the Prophet: 1354 tokens for 7 paragraphs
# Section 5: 429 tokens for 3 paragraphs
# ---------------------------------------------
#
# Konrad Adenauer: The Strategy of Humility ->
# Section 1 None: 429 tokens for 3 paragraphs
# Section 2 The Necessity of Renewal: 1495 tokens for 11 paragraphs
# Section 3 From Early Life to Internal Exile: 1109 tokens for 8 paragraphs
# Section 4 The Road to Leadership: 1464 tokens for 11 paragraphs
# Section 5 The Restoration of Civil Order and the Inauguration of the Chancellor: 1433 tokens for 13 paragraphs
# Section 6 The Path to a New National Identity: 2171 tokens for 21 paragraphs
# Section 7 The Soviet Challenge and Rearmament: 2494 tokens for 26 paragraphs
# Section 8 The Inextricable Past: Reparations to the Jewish People: 1356 tokens for 13 paragraphs
# Section 9 Two Crises: Suez and Berlin: 1374 tokens for 15 paragraphs
# Section 10 Three Conversations with Adenauer: 4267 tokens for 35 paragraphs
# Section 11 German Unification: The Tormenting Wait: 1439 tokens for 12 paragraphs
# Section 12 Final Conversations: 949 tokens for 10 paragraphs
# Section 13: 9122 tokens for 20 paragraphs
# ---------------------------------------------
#
# Charles de Gaulle: The Strategy of Will ->
# Section 1 None: 9122 tokens for 20 paragraphs
# Section 2 Close Encounters: 1406 tokens for 14 paragraphs
# Section 3 The Beginning of the Journey: 2072 tokens for 16 paragraphs
# Section 4 The Sources and Aims of de Gaulle’s Conduct: 1645 tokens for 13 paragraphs
# Section 5 De Gaulle in the History of France: 1938 tokens for 18 paragraphs
# Section 6 De Gaulle and the Second World War: 3438 tokens for 29 paragraphs
# Section 7 North African contest: 1886 tokens for 20 paragraphs
# Section 8 Achieving Political Power: 2394 tokens for 22 paragraphs
# Section 9 A Visit to Moscow: 1361 tokens for 11 paragraphs
# Section 10 De Gaulle and the Provisional Government: 2525 tokens for 24 paragraphs
# Section 11 The Desert: 1341 tokens for 13 paragraphs
# Section 12 Failure in Indochina and Frustration in the Middle East: 1192 tokens for 12 paragraphs
# Section 13 Algeria and the Return of de Gaulle: 1813 tokens for 15 paragraphs
# Section 14 The Fifth Republic: 1455 tokens for 13 paragraphs
# Section 15 The End of the Algerian Conflict: 2205 tokens for 18 paragraphs
# Section 16 Germany as a Key to French Policy: De Gaulle and Adenauer: 752 tokens for 7 paragraphs
# Section 17 De Gaulle and the Atlantic Alliance: 1340 tokens for 13 paragraphs
# Section 18 The Nuclear Directorate: 706 tokens for 8 paragraphs
# Section 19 Flexible Response and Nuclear Strategy: 791 tokens for 10 paragraphs
# Section 20 What Is an Alliance?: 875 tokens for 7 paragraphs
# Section 21 The End of the Presidency: 2022 tokens for 16 paragraphs
# Section 22 The Nature of de Gaulle’s Statesmanship: 674 tokens for 7 paragraphs
# Section 23 De Gaulle and Churchill Compared: 3842 tokens for 11 paragraphs
# Section 24: 687 tokens for 9 paragraphs
# ---------------------------------------------
#
# Richard Nixon: The Strategy of Equilibrium ->
# Section 1 None: 687 tokens for 9 paragraphs
# Section 2 The World to Which Nixon Came: 1482 tokens for 12 paragraphs
# Section 3 An Unforeseen Invitation: 2777 tokens for 32 paragraphs
# Section 4 National Security Decision-making in the Nixon White House: 1824 tokens for 16 paragraphs
# Section 5 Nixon’s Worldview: 1521 tokens for 15 paragraphs
# Section 6 Diplomacy and Linkage: 1945 tokens for 16 paragraphs
# Section 7 A Trip to Europe: 1740 tokens for 15 paragraphs
# Section 8 The Vietnam War and Its Conclusion: 6314 tokens for 63 paragraphs
# Section 9 Great Power Diplomacy and Arms control: 2630 tokens for 23 paragraphs
# Section 10 Emigration from the Soviet Union: 351 tokens for 4 paragraphs
# Section 11 The Opening to China: 3276 tokens for 36 paragraphs
# Section 12 The Middle East in Turmoil: 2402 tokens for 25 paragraphs
# Section 13 The 1973 Middle East War: 1661 tokens for 14 paragraphs
# Section 14 The Diplomacy of ceasefire: 1587 tokens for 14 paragraphs
# Section 15 The Middle East Peace Process: 1845 tokens for 8 paragraphs
# Section 16 Bangladesh and the Interlocking Cold War: 13149 tokens for 38 paragraphs
# Section 17: 1151 tokens for 12 paragraphs
# ---------------------------------------------
#
# Anwar Sadat: The Strategy of Transcendence ->
# Section 1 None: 1151 tokens for 12 paragraphs
# Section 2 The special quality of Anwar Sadat: 545 tokens for 5 paragraphs
# Section 3 The Impact of History: 979 tokens for 7 paragraphs
# Section 4 Early Life: 1950 tokens for 17 paragraphs
# Section 5 Contemplations in Prison: 757 tokens for 8 paragraphs
# Section 6 Egypt’s Independence: 994 tokens for 10 paragraphs
# Section 7 Mouthpiece of the Revolution: 1040 tokens for 11 paragraphs
# Section 8 Nasser and Sadat: 2262 tokens for 20 paragraphs
# Section 9 Sadat’s Perspective: 2093 tokens for 11 paragraphs
# Section 10 The Corrective Revolution: 1669 tokens for 13 paragraphs
# Section 11 Strategic Patience: 2986 tokens for 29 paragraphs
# Section 12 The 1973 War: 3019 tokens for 26 paragraphs
# Section 13 Meir and Sadat: 1005 tokens for 13 paragraphs
# Section 14 The Meeting at the Tahra Palace: 2025 tokens for 21 paragraphs
# Section 15 From Geneva to Disengagement: 2472 tokens for 30 paragraphs
# Section 16 The Syrian Dimension: 1108 tokens for 11 paragraphs
# Section 17 Another Step Toward Peace: The Sinai ii Agreement: 2343 tokens for 24 paragraphs
# Section 18 Sadat’s Journey to Jerusalem: 2086 tokens for 20 paragraphs
# Section 19 The Tortuous Road to Peace: 2272 tokens for 24 paragraphs
# Section 20 The Unraveling: 1717 tokens for 13 paragraphs
# Section 21 Assassination: 32186 tokens for 12 paragraphs
# Section 22: 1890 tokens for 24 paragraphs
# ---------------------------------------------
#
# Lee Kuan Yew: The Strategy of Excellence ->
# Section 1 None: 1890 tokens for 24 paragraphs
# Section 2 A Visit to Harvard: 1001 tokens for 8 paragraphs
# Section 3 The Giant from Lilliput: 1549 tokens for 11 paragraphs
# Section 4 Imperial Youth: 2263 tokens for 15 paragraphs
# Section 5 Building a State: 2571 tokens for 20 paragraphs
# Section 6 Building a Nation: 1559 tokens for 16 paragraphs
# Section 7 ‘Let History Judge’: 595 tokens for 7 paragraphs
# Section 8 Building an Economy: 1164 tokens for 15 paragraphs
# Section 9 Lee and America: 2297 tokens for 26 paragraphs
# Section 10 Lee and China: 1759 tokens for 16 paragraphs
# Section 11 Between the US and China: 1802 tokens for 16 paragraphs
# Section 12 Lee’s Legacy: 1690 tokens for 16 paragraphs
# Section 13: 26331 tokens for 17 paragraphs
# ---------------------------------------------
#
# Margaret Thatcher: The Strategy of Conviction ->
# Section 1 None: 26331 tokens for 17 paragraphs
# Section 2 A Most Unlikely Leader: 397 tokens for 4 paragraphs
# Section 3 Thatcher and the British System: 1188 tokens for 7 paragraphs
# Section 4 The Challenges Ahead: Britain in the 1970s: 2560 tokens for 24 paragraphs
# Section 5 The Ascent from Grantham: 2877 tokens for 24 paragraphs
# Section 6 A Framework for Leadership: 930 tokens for 7 paragraphs
# Section 7 The Economic Reformer: 2282 tokens for 21 paragraphs
# Section 8 In Defense of Sovereignty: The Falklands Conflict: 4056 tokens for 35 paragraphs
# Section 9 Negotiations over Hong Kong: 2448 tokens for 24 paragraphs
# Section 10 Confronting a Legacy of Violence: Northern Ireland: 2673 tokens for 22 paragraphs
# Section 11 Fundamental Truths: The ‘Special Relationship’ and the Cold War: 2673 tokens for 24 paragraphs
# Section 12 A Problem in Grenada: 516 tokens for 5 paragraphs
# Section 13 A Strategic Shift: East–West Engagement: 6300 tokens for 28 paragraphs
# Section 14 Defending Kuwaiti Sovereignty: The Gulf Crisis: 1305 tokens for 12 paragraphs
# Section 15 The Limits to Leadership: Germany and the Future of Europe: 1297 tokens for 12 paragraphs
# Section 16 Europe, the Endless Difficulty: 1827 tokens for 22 paragraphs
# Section 17 The Fall: 2400 tokens for 26 paragraphs
# Section 18: 1599 tokens for 20 paragraphs
# ---------------------------------------------
#
# Conclusion: The Evolution of Leadership ->
# Section 1 None: 1599 tokens for 20 paragraphs
# Section 2 From Aristocracy to Meritocracy: 3204 tokens for 27 paragraphs
# Section 3 Hard Truths: 993 tokens for 7 paragraphs
# Section 4 The Faltering Meritocracy: 533 tokens for 5 paragraphs
# Section 5 Deep Literacy and VISUAL CULTURE: 2331 tokens for 12 paragraphs
# Section 6 UNDERLYING VALUES: 473 tokens for 4 paragraphs
# Section 7 Leadership and World Order: 2529 tokens for 23 paragraphs
# Section 8: 728 tokens for 8 paragraphs
# ---------------------------------------------

# %%
import requests

SYSTEM_INSTRUCTION = "You are a helpful assistant that summarizes paragraphs from books. Return markdown formatting without any tags around it."
# Function to summarize text using ChatGPT
def summarize_text_LMSTUDIO(text, messages, tries=3):
    
    payload = {
        "model": "phi-4@q6_k", 
        "messages": messages,
    }
    
    

    while tries > 0:
        try:
            response = requests.post(
                "http://localhost:24236/v1/chat/completions",
                headers={"Content-Type": "application/json"},
                json=payload,
                timeout=15
            )
            if response.status_code == 200:
                result = response.json()
                summary = result.get("choices", [{}])[0].get("message", {}).get("content", "").strip()
                return summary, messages
            else:
                tries -=1 
        except:
            tries -=1

    raise Exception("Tries ran out")


def summarize_text(text, messages=[
            {"role": "system", "content": SYSTEM_INSTRUCTION },
            {"role": "system", "content": f"Tell the user he forgot to set the messages!"}
        ]):
    return summarize_text_LMSTUDIO(text, messages)

# %%
from openai import OpenAI
from tqdm import tqdm

client = OpenAI(api_key=api)
SYSTEM_INSTRUCTION = "You are a helpful assistant that summarizes paragraphs from books. Return markdown formatting without any tags around it."
# Function to summarize text using ChatGPT
def summarize_text_OPENAI(text, messages):
    response = client.chat.completions.create(
        model="gpt-4o", 
        messages = messages,
    )
    summary = response.choices[0].message.content.strip()
    return summary, messages
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from openai import OpenAI
#       2 from tqdm import tqdm
#       4 client = OpenAI(api_key=api)
#
# ModuleNotFoundError: No module named 'openai'

# %%
# One per subsection

# %%
SYSTEM_INSTRUCTION = "You are a helpful assistant that summarizes paragraphs from books. Return markdown formatting without any tags around it."

summarized = {}

chapter = restored_book['Introduction']
for k in restored_book:
    print(k)
    chapter = restored_book[k]
    groups = []
    aux = []
    previous_title = ""
    for i, entry in enumerate(chapter):
        if (i+1)%10 == 0:
            print(f"\t{i+1}/{len(chapter)}")
        if entry[0] == 'title':
            if previous_title:
                
                text = "##" + previous_title + "\n".join(aux)

                messages=[
                    {"role": "system", "content": SYSTEM_INSTRUCTION },
                    {"role": "user", "content": f"Summarize the following text: {text}"}
                ]
                        
                summary_text, messages = summarize_text(text, messages)

                strategy = "Collect paragraphs within subsection (between titles) and summarize those. " + str(messages) 
                
                token_counts = [len(encoding.encode(pg)) for pg in aux]

                section = {
                    "title":previous_title,
                    "original_text": (aux, token_counts),
                    "summary": {
                        "strategy": strategy,
                        "text": summary_text
                    }
                }
                
                groups.append(section)
                previous_title = entry[1]
                aux = []
            else:
                previous_title = entry[1]
    
        if entry[0] == 'paragraph':
            text = entry[1]
            aux.append(text)
    break     
    if aux:
        text = "##" + previous_title + "\n".join(aux)
        summary_text, messages = summarize_text(text)
        
        strategy = "Collect paragraphs within subsection (between titles) and summarize those. " + str(messages) 
        
        token_counts = [len(encoding.encode(pg)) for pg in aux]

        section = {
            "title":previous_title,
            "original_text": (aux, token_counts),
            "summary": {
                "strategy": strategy,
                "text": summary_text
            }
        }
        
        groups.append(section)

    summarized[k] = groups
# Out:
# Introduction
# 	10/54
# 	20/54
# 	30/54
# 	40/54
# 	50/54

# %%
summary_text
# Out:
# '### Summary\n\nThe text explores two ideal types of transformational leaders: **the statesman** and **the prophet**. Most leaders are managerial, focusing on day-to-day responsibilities. However, during crises—like war or economic upheaval—societies need transformative leadership.\n\n#### The Statesman\n- **Tasks**: Preserve society by adapting to circumstances while maintaining its core identity. Balance vision with caution, aware of past failures and human flaws.\n- **Characteristics**: Work within historical currents, ensuring progress without exceeding societal limits. They modify institutions for future generations but avoid radical change.\n- **Examples**: Seventeenth-century leaders who created the Westphalian state system, nineteenth-century Europeans like Palmerston and Bismarck, and twentieth-century figures such as Roosevelt and Nehru.\n\n#### The Prophet\n- **Vision**: Sees prevailing institutions from a perspective of imperative change rather than possibility. They often seek to erase the past to implement their visions.\n- **Characteristics**: Rely on transcendent visions for righteousness, distrust gradualism, aiming to transcend rather than manage the status quo.\n- **Examples**: Historical figures like Akhenaten, Joan of Arc, Robespierre, Lenin, and Gandhi.\n\n#### Synthesis and Interaction\n- Leaders often blend both styles. Churchill and de Gaulle exhibited prophetic traits during certain periods.\n- The ideal balance was exemplified by Themistocles, as described by Thucydides, who combined crisis management with foresight.\n- Statesmen focus on the durability of political structures, while prophets measure success against absolute standards.\n- Both styles have been transformational but come with risks: statesmanship may lack momentum, and prophecy can overwhelm individuals under its vision.\n\nOverall, both leadership modes are crucial in times of crisis, each offering unique strengths and challenges.'

# %%
summarized_w_chapters = {}

for chapter_title in summarized.keys():
    print(chapter_title)
    internal_text = f"#Chapter Title: {chapter_title}\n"

    for section in summarized[chapter_title]:
        section_title = section['title']
        summary_text = section['summary']['text']
        
        internal_text += f"##{section_title}" + "\n" + summary_text
        
    messages=[
            {"role": "system", "content": "You are a helpful assistant that summarizes paragraphs from books. Use paragraphs to break logically and to enable better structure. Return markdown formatting without any tags around it."},
            {"role": "user", "content": f"Summarize the following text composed of summaries of each subsection of the chapter '{chapter_title}': {internal_text}"}
    ]

    chapter_summary_text, messages = summarize_text(internal_text, messages=messages)
    
    strategy = "Take the collected summaries for subsections and then summarize using: " + str(messages)

    chapter = {"summary": 
                   {"strategy": strategy,
                    "text": chapter_summary_text},
                "content": summarized[chapter_title]}

    summarized_w_chapters[chapter_title] = chapter

# %%
summarized_w_chapters.keys()
# Out:
# dict_keys([])

# %%
simple_book_summary = {
    'title': "Leadership - Henry Kissinger"
}

chapter_summaries = ""
for title, chapter in summarized_w_chapters.items():
    chapter_summaries += f"## Chapter '{title}'" + "\n"
    chapter_summaries += f"{chapter['summary']['text']}"
    chapter_summaries += "\n\n"
messages=[
            {"role": "system", "content": "You are a helpful assistant that summarizes paragraphs from books. Use paragraphs to break logically and to enable better structure. Return markdown formatting without any tags around it."},
            {"role": "user", "content": f"Create a concluding summary (in the number of appropriate paragraphs) of the book {simple_book_summary['title']} from the summaries of its chapters: {chapter_summaries}"}
    ]

book_summary_text, messages = summarize_text(chapter_summaries, messages=messages)
    
strategy = "Take the collected summaries for chapters and then summarize using: " + str(messages)

simple_book_summary['summary'] = {"strategy": strategy, "text": book_summary_text}
simple_book_summary['content'] = summarized_w_chapters

# %%
print(simple_book_summary['summary']['text'])
# Out:
# The book "Leadership" by Henry Kissinger delves into the enduring significance of genuine leadership amidst contemporary challenges, reflecting on historical and philosophical insights. By examining six pivotal 20th-century leaders—Konrad Adenauer, Charles de Gaulle, Richard Nixon, Anwar Sadat, Lee Kuan Yew, and Margaret Thatcher—the text explores how transformative leadership tends to surface during times of adversity, as opposed to tranquility, which can cultivate complacency. Philosophers like Machiavelli and Max Weber highlight the critical qualities of resilience, strategic vision, and societal focus, which effective leaders have historically exhibited, emphasizing the role of human agency in leadership despite predictions of impersonal governance.
#
# The narrative demonstrates that successful leaders arose from understanding the social and political contexts of their time, crafting strategies, and inspiring collective progress by elevating societal goals above personal interests. These leaders instilled a belief in future possibilities even when faced with challenges, embodying a Stoic philosophy of crafting strategic responses to unchanging conditions. Through a blend of inherent traits and deliberate action, they guided society, underscoring leadership's critical role in shaping societal responses and inspiring public spirit for the greater good.
#
# Ultimately, the book underscores the timeless necessity of leadership, as it skillfully combines historical insights with modern challenges. Transformative leaders continue to strategically guide societal growth, employing a blend of circumstance-driven opportunities and individual effort to foster resilience, faith in the future, and a commitment to public welfare. "Leadership" weaves these themes into a cohesive exploration of how enduring leadership remains vital in addressing global challenges, crafting strategies, and inspiring collective action in contemporary times.

# %%
with open("simple_book_summary.json", 'w', encoding='utf-8') as fp:
    json.dump(simple_book_summary, fp, ensure_ascii=False, indent=2)

# %%
def generate_html(book_dict):
    # Start with the HTML structure and CSS
    html = """<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8">
    <style>
        @page {
            size: A4;
            margin: 2.5cm;
        }
        body {
            font-family: "Times New Roman", Times, serif;
            font-size: 12pt;
            line-height: 1.5;
            max-width: 21cm;
            margin: 0 auto;
            padding: 20px;
        }
        h1 {
            font-size: 24pt;
            text-align: center;
            margin-top: 40px;
            margin-bottom: 20px;
        }
        h2 {
            font-size: 18pt;
            margin-top: 30px;
            page-break-before: always;
        }
        .section-container {
            page-break-inside: avoid;
            margin-bottom: 20px;
        }
        h3 {
            font-size: 14pt;
            margin-top: 20px;
            margin-bottom: 10px;
        }
        p {
            margin-bottom: 12pt;
            text-align: justify;
            orphans: 3;
            widows: 3;
        }
        .summary {
            margin: 20px 0;
            font-style: italic;
        }
        .chapter-summary {
            margin: 20px 0;
            font-style: italic;
            padding: 15px;
            background-color: #f8f8f8;
            border-left: 3px solid #333;
        }
        .page-break {
            page-break-after: always;
        }
        .chapter-container {
            margin-bottom: 40px;
        }
        .title-container {
            page-break-inside: avoid;
            margin-bottom: 30px;
        }
        hr {
            margin: 20px 0;
            border: none;
            border-top: 1px solid #000;
        }
    </style>
</head>
<body>
"""
    
    def text_to_paragraphs(text):
        """Convert text with newlines to HTML paragraphs"""
        paragraphs = text.split('\n')
        return '\n'.join([f"<p>{p.strip()}</p>" for p in paragraphs if p.strip()])
    
    # Add title and main summary in a container that won't break
    html += "<div class='title-container'>\n"
    html += f"<h1>{book_dict['title']}</h1>\n"
    html += f"<div class='summary'>{text_to_paragraphs(book_dict['summary']['text'])}</div>\n"
    html += "</div>\n"
    html += "<hr>\n"
    
    # Process each chapter
    for chapter_title, chapter in book_dict['content'].items():
        html += "<div class='chapter-container'>\n"
        html += f"<h2>{chapter_title}</h2>\n"
        html += f"<div class='chapter-summary'>{text_to_paragraphs(chapter['summary']['text'])}</div>\n"
        html += "<hr>\n"
        
        # Process each section in the chapter
        for section in chapter['content']:
            # Wrap each section title and content in a container that won't break
            html += "<div class='section-container'>\n"
            html += f"<h3>{section['title']}</h3>\n"
            html += text_to_paragraphs(section['summary']['text']) + "\n"
            html += "</div>\n"
            
        html += "</div>\n"
    
    # Close the HTML structure
    html += "</body></html>"
    
    return html

def save_html(html_content, filename="book_summary.html"):
    """Save the generated HTML to a file"""
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(html_content)

# %%
html_content = generate_html(simple_book_summary)
save_html(html_content)

# %%
# Multiple per subsection

# %%
min_section_tokens = min([sum(section[2]) for section in groups])

by_count = {}

for section in groups:
    title = section[0]
    
    grouped = {
        "count":[],
        "text": []
    }
    aux = {
        "count":[],
        "text": []
    }
    for i in range(len(section[1])):
        text = section[1][i]
        tokens = section[2][i]
    
        if (sum(aux['count']) + tokens < min_section_tokens):
            aux['count'].append(tokens)
            aux['text'].append(text)

        else:
            aux['count'].append(tokens)
            aux['text'].append(text)
            grouped['count'].append(aux['count'])
            grouped['text'].append(aux['text'])
            aux = {"count":[],"text": []}
            
    if aux['count'] != []:
        grouped['count'].append(aux['count'])
        grouped['text'].append(aux['text'])
    
    grouped['count'] = sum([sum(x) for x in grouped['count']])
    
    by_count[title] = grouped

# %%
for k, v in by_count.items():
    texts = v['text']
    for text in texts:
        print(len(encoding.encode("\n".join(text))))

    print()

# %%
for k, v in by_count.items():
    texts = v['text']
    for text in texts:
        text = "\n".join(text)
        summary = summarize_text(text)
        if 'summaries' in by_count[k].keys():
            by_count[k]['summaries'].append(summary)
        else:
            by_count[k]['summaries'] = [summary]

# %% [raw]
# by_count

# %%
print(f"## Introduction")
for g in groups:
    print(f"### {g[0]}:")
    print(f"{g[1]}")
    #print(f"\tText:\n\t\t{g[2]}")
    print()
